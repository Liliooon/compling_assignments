# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью LDA в gensim и NMF в sklearn**.
#
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) повторите пункт 4 на преобразованном корпусе (подбирайте параметры, ориентируясь на качество, а не на результаты, которые вы получали без tfidf);
#
# 8) в отдельной ячейке сравните лучшую модель без tfidf и лучшую модель с tfidf (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте темы лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **
#
#
# Острожнее интерпретируйте полученные результаты. Если один алгоритм сработал хорошо в этом задании - не значит, что он всегда будет хорошо работать, и наоборот.

# %% [markdown]
# ## 1.

# %%
from string import punctuation as punct
import re
import gensim
import pymorphy2
import numpy as np
from nltk.tokenize import word_tokenize
from stop_words import get_stop_words

# %%
accents = {
    '́': '',
    '̀': '',
    'а́': 'а',
    'а̀': 'а',
    'е́': 'е',
    'ѐ': 'е',
    'и́': 'и',
    'ѝ': 'и',
    'о́': 'о',
    'о̀': 'о',
    'у́': 'у',
    'у̀': 'у',
    'ы́': 'ы',
    'ы̀': 'ы',
    'э́': 'э',
    'э̀': 'э',
    'ю́': 'ю',
    '̀ю': 'ю',
    'я́́': 'я',
    'я̀': 'я',
}

# %%
punct += '…«»–'

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
stop_words = get_stop_words('ru')

# %%
with open('wiki_data.txt') as f:
    texts = f.readlines()[:10000]

# %%
def normalize_text(text):
    tokens = [token.strip(punct) for token 
              in word_tokenize(text, language='russian') 
              if re.search(r'[a-zа-яё]', token, re.I)]
    tokens_without_accents = [''.join(accents.get(ch, ch) for ch in token.lower()) 
                              for token in tokens] # чтобы убрать ударения 
    lemmas = [morph.parse(token)[0].normal_form for token in tokens_without_accents]
    lemmas_without_stops = [lemma for lemma in lemmas if lemma not in stop_words]
    return lemmas_without_stops

# %%
texts = [normalize_text(text) for text in texts]

# %% [markdown]
# ## 2.

# %%
# для нграммов
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) 
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts]

# %% [markdown]
# ## 3.

# %%
ngrammed_texts = list(ngrammed_texts)

# %%
for i, text in enumerate(ngrammed_texts):
    ngrammed_texts[i] = [word for word in text if len(word) > 2]

# %%
dictionary = gensim.corpora.Dictionary(ngrammed_texts)

# %%
dictionary.filter_extremes(no_above=0.1, no_below=10)
dictionary.compactify()

# %% [markdown]
# ## 4.

# %%
ngrammed_texts = [ngrammed_text for ngrammed_text in ngrammed_texts if ngrammed_text]

# %%
corpus = [dictionary.doc2bow(ngrammed_text) for ngrammed_text in ngrammed_texts]

# %%
ldas = {}

# %%
ldas['lda_1'] = gensim.models.LdaMulticore(corpus,
                                           num_topics=20,
                                           id2word=dictionary,
                                           passes=30)

# %%
ldas['lda_2'] = gensim.models.LdaMulticore(corpus,
                                           num_topics=20,
                                           alpha='asymmetric',
                                           id2word=dictionary,
                                           passes=30)

# %%
ldas['lda_3'] = gensim.models.LdaMulticore(corpus,
                                           num_topics=20,
                                           alpha=10,
                                           id2word=dictionary,
                                           passes=30)

# %%
ldas['lda_4'] = gensim.models.LdaMulticore(corpus,
                                           num_topics=20,
                                           alpha=0.001,
                                           id2word=dictionary,
                                           passes=30)

# %%
ldas['lda_5'] = gensim.models.LdaMulticore(corpus,
                                           num_topics=20,
                                           eta=10,
                                           id2word=dictionary,
                                           passes=30)

# %%
ldas['lda_6'] = gensim.models.LdaMulticore(corpus,
                                           num_topics=20,
                                           eta=0.001,
                                           id2word=dictionary,
                                           passes=30)

# %%
def pretty_print_topics(lda):
    for topic in sorted(lda.print_topics(num_topics=100, num_words=7)):
        topic_words = topic[1].replace('_', ' ')
        print(topic[0] + 1, end='. ')
        print(*re.findall(r'"(.+?)"', topic_words), sep=', ', end='\n\n')

# %%
for lda in ldas:
    print(lda)
    pretty_print_topics(ldas[lda])
# Out:
# lda_1
# 1. войско, армия, фронт, посёлок, станция, дивизия, улица
#
# 2. хутор, поселение, входить состав, район ростовский, право, ростовский область, сельский поселение
#
# 3. село, остров, река, корабль, экспедиция, северный, озеро
#
# 4. фильм, роль, сша, сериал, американский, актёр, сезон
#
# 5. олимпийский игра, свой история, игра, завоевать медаль, летний олимпийский, принимать участие, участие летний
#
# 6. игра, компания, версия, использовать, серия, выпустить, система
#
# 7. площадь км², составлять почтовый, индекс телефонный, код занимать, основать находиться, код коатуа, село
#
# 8. автомобиль, подвеска, модель, значение, флаг, колесо, использоваться
#
# 9. система, должный, случай, результат, проект, исследование, использовать
#
# 10. фильм, книга, доктор, роман, слово, говорить, отец
#
# 11. группа, песня, альбом, музыка, музыкальный, театр, выпустить
#
# 12. вид, растение, некоторый, встречаться, семейство, лист, форма
#
# 13. церковь, здание, дом, храм, музей, улица, художник
#
# 14. страна, король, территория, вино, пешка, украина, чёрный
#
# 15. университет, институт, член, школа, ссср, окончить, москва
#
# 16. сын, король, смерть, война, дочь, власть, брат
#
# 17. занимать площадь, область код, перепись составлять, коатуа население, почтовый индекс, телефонный код, район житомирский
#
# 18. команда, клуб, сезон, матч, турнир, сборная, чемпионат
#
# 19. уезд, округ, территория, население, волость, центр, деревня
#
# 20. армия, война, бой, август, военный, октябрь, сентябрь
#
# lda_2
# 1. олимпийский игра, свой история, район житомирский, занимать площадь, область код, перепись составлять, завоевать медаль
#
# 2. составлять почтовый, индекс телефонный, площадь км², код занимать, основать находиться, код коатуа, книга
#
# 3. армия, фронт, войско, дивизия, бой, противник, остров
#
# 4. село, река, население, озеро, территория, составлять, житель
#
# 5. москва, русский, ссср, окончить, институт, школа, советский
#
# 6. турнир, игра, выиграть, команда, соревнование, матч, победа
#
# 7. церковь, храм, святой, монастырь, король, епископ, н э
#
# 8. здание, университет, музей, проект, центр, школа, государственный
#
# 9. корабль, остров, флот, судно, морской, море, экспедиция
#
# 10. вид, животное, растение, вода, некоторый, встречаться, семейство
#
# 11. игра, уезд, специальный район, игрок, городской округ, создать, кнр
#
# 12. группа, песня, альбом, музыка, музыкальный, the, выпустить
#
# 13. доктор, модель, серия, автомобиль, эпизод, двигатель, звезда
#
# 14. фильм, сын, отец, роль, дочь, смерть, жена
#
# 15. война, армия, военный, войско, отряд, сила, немецкий
#
# 16. компания, самолёт, сша, завод, производство, предприятие, американский
#
# 17. использовать, система, использоваться, использование, например, версия, случай
#
# 18. улица, станция, автомобиль, подвеска, система, мост, строительство
#
# 19. клуб, команда, сезон, матч, чемпионат, выступать, игрок
#
# 20. партия, член, право, президент, россия, дело, совет
#
# lda_3
# 1. право, россия, ребёнок, брак, суд, российский, проект
#
# 2. команда, клуб, сезон, матч, турнир, игра, сборная
#
# 3. игра, корабль, экспедиция, остров, версия, судно, компания
#
# 4. система, вид, использовать, животное, например, случай, некоторый
#
# 5. альбом, песня, группа, фильм, выпустить, музыка, музыкальный
#
# 6. фильм, доктор, роль, серия, сериал, эпизод, актёр
#
# 7. уезд, король, территория, власть, страна, сын, россия
#
# 8. церковь, здание, музей, епархия, россия, русский, строительство
#
# 9. вместе, участвовать, бой, девушка, август, декабрь, апрель
#
# 10. партия, член, президент, политический, совет, организация, правительство
#
# 11. картина, село, олимпийский игра, река, москва, изобразить, территория
#
# 12. село, земля, школа, церковь, уезд, территория, река
#
# 13. университет, профессор, убить, завод, война, институт, убийство
#
# 14. китайский, сын, отец, китай, дом, жена, роман
#
# 15. село, деревня, население, марка, река, округ, центр
#
# 16. участник, площадь км², село, олимпиада, олимпийский игра, код занимать, группа
#
# 17. храм, монастырь, святой, дом, церковь, собор, епископ
#
# 18. вид, растение, н э, период, лист, век, искусство
#
# 19. армия, войско, фронт, автомобиль, противник, дивизия, бой
#
# 20. канада, составлять почтовый, олимпийский игра, индекс телефонный, свой история, компания, основать находиться
#
# lda_4
# 1. игра, группа, альбом, песня, выпустить, версия, the
#
# 2. турнир, король, открытый чемпионат, финал, выиграть, пара, пешка
#
# 3. страна, право, государство, россия, закон, общество, сша
#
# 4. армия, войско, фронт, война, дивизия, август, военный
#
# 5. дело, суд, москва, убийство, убить, арестовать, март
#
# 6. корабль, самолёт, война, флот, войско, отряд, военный
#
# 7. система, автомобиль, использовать, использоваться, модель, тип, значение
#
# 8. остров, река, озеро, территория, северный, вода, экспедиция
#
# 9. индекс телефонный, составлять почтовый, площадь км², код занимать, район житомирский, основать находиться, занимать площадь
#
# 10. университет, институт, школа, профессор, окончить, ссср, книга
#
# 11. фильм, книга, роль, серия, доктор, ребёнок, отец
#
# 12. церковь, сын, храм, король, святой, здание, монастырь
#
# 13. клуб, команда, сезон, матч, сборная, выступать, игра
#
# 14. партия, член, совет, президент, правительство, выборы, политический
#
# 15. вид, растение, семейство, лист, встречаться, животное, некоторый
#
# 16. гонка, сезон, команда, чемпионат мир, декабрь, победа, февраль
#
# 17. село, посёлок, улица, деревня, хутор, поселение, население
#
# 18. уезд, театр, специальный район, музыка, режиссёр, музыкальный, создать
#
# 19. компания, проект, производство, язык, предприятие, россия, крупный
#
# 20. олимпийский игра, свой история, игра, завоевать медаль, летний олимпийский, принимать участие, участие летний
#
# lda_5
# 1. венера, дельта, плёнка, александр николаевич, виноградов, иван иванович, назвать честь
#
# 2. игра, команда, клуб, сезон, олимпийский игра, матч, свой история
#
# 3. армия, война, компания, система, войско, группа, август
#
# 4. pour, код занимать, индекс телефонный, составлять почтовый, площадь км², les, основать находиться
#
# 5. ана, ангела, многозначный, дельта, понятие, венера, спасатель
#
# 6. село, река, территория, остров, улица, посёлок, население
#
# 7. составлять почтовый, индекс телефонный, код занимать, площадь км², район житомирский, основать находиться, область код
#
# 8. уезд, специальный район, городской округ, городской уезд, кнр, образовать, переименовать
#
# 9. автомобиль, подвеска, колесо, рычаг, кузов, поворот, задний
#
# 10. николай василиевич, село, плёнка, многозначный, орлов, александр василиевич, попов
#
# 11. альбом, группа, песня, сингл, выпустить, the, записать
#
# 12. вид, растение, семейство, встречаться, лист, смотреть, некоторый
#
# 13. николай василиевич, ангела, аббревиатура, многозначный, лихтенштейн, регент, попов
#
# 14. спасатель, юрта, ангела, кузнецов, плёнка, александр михаилович, дельта
#
# 15. спасатель, плёнка, иван иванович, ефим, луция, николай иванович, калинин
#
# 16. фильм, книга, дом, песня, церковь, роль, отец
#
# 17. николай николаевич, некрасов, венера, дельта, николай василиевич, попов, кузнецов
#
# 18. чак, убежище, концовка, нашествие, лифт, арена, edition
#
# 19. фронт, герой советский, отечественный война, дивизия, участник великий, верховный совет, противник
#
# 20. ана, многозначный, иван иванович, азиатский, луция, понятие, поблизости
#
# lda_6
# 1. уезд, сын, специальный район, граф, округ, волость, образовать
#
# 2. книга, россия, право, история, закон, страна, отношение
#
# 3. остров, автомобиль, вода, подвеска, северный, небольшой, высокий
#
# 4. компания, система, завод, модель, самолёт, производство, станция
#
# 5. армия, войско, война, фронт, дивизия, военный, бой
#
# 6. село, река, посёлок, деревня, территория, хутор, поселение
#
# 7. песня, музыка, музыкальный, композитор, марка, театр, концерт
#
# 8. игра, компания, команда, игрок, уровень, бой, персонаж
#
# 9. система, использовать, использование, метод, программа, использоваться, исследование
#
# 10. вид, растение, животное, семейство, флаг, некоторый, лист
#
# 11. группа, альбом, перепись составлять, коатуа население, область код, почтовый индекс, занимать площадь
#
# 12. церковь, храм, здание, дом, святой, монастырь, король
#
# 13. команда, клуб, сезон, матч, турнир, сборная, выиграть
#
# 14. улица, музей, канада, население, художник, территория, сша
#
# 15. язык, н э, слово, значение, народ, царь, греческий
#
# 16. площадь км², индекс телефонный, составлять почтовый, код занимать, основать находиться, код коатуа, район житомирский
#
# 17. олимпийский игра, свой история, игра, завоевать медаль, летний олимпийский, принимать участие, участие летний
#
# 18. университет, член, партия, россия, ссср, институт, президент
#
# 19. фильм, роль, отец, доктор, сериал, режиссёр, серия
#
# 20. корабль, флот, экспедиция, морской, норвегия, море, остров

# %% [markdown]
# ## 5.

# %% [markdown]
# На мой взгляд, лучше всего получилась `lda_4` с параметром `alpha=0.001`:

# %%
pretty_print_topics(ldas['lda_4'])
# Out:
# 1. игра, группа, альбом, песня, выпустить, версия, the
#
# 2. турнир, король, открытый чемпионат, финал, выиграть, пара, пешка
#
# 3. страна, право, государство, россия, закон, общество, сша
#
# 4. армия, войско, фронт, война, дивизия, август, военный
#
# 5. дело, суд, москва, убийство, убить, арестовать, март
#
# 6. корабль, самолёт, война, флот, войско, отряд, военный
#
# 7. система, автомобиль, использовать, использоваться, модель, тип, значение
#
# 8. остров, река, озеро, территория, северный, вода, экспедиция
#
# 9. индекс телефонный, составлять почтовый, площадь км², код занимать, район житомирский, основать находиться, занимать площадь
#
# 10. университет, институт, школа, профессор, окончить, ссср, книга
#
# 11. фильм, книга, роль, серия, доктор, ребёнок, отец
#
# 12. церковь, сын, храм, король, святой, здание, монастырь
#
# 13. клуб, команда, сезон, матч, сборная, выступать, игра
#
# 14. партия, член, совет, президент, правительство, выборы, политический
#
# 15. вид, растение, семейство, лист, встречаться, животное, некоторый
#
# 16. гонка, сезон, команда, чемпионат мир, декабрь, победа, февраль
#
# 17. село, посёлок, улица, деревня, хутор, поселение, население
#
# 18. уезд, театр, специальный район, музыка, режиссёр, музыкальный, создать
#
# 19. компания, проект, производство, язык, предприятие, россия, крупный
#
# 20. олимпийский игра, свой история, игра, завоевать медаль, летний олимпийский, принимать участие, участие летний

# %% [markdown]
# Лучшие три темы из нее:
#
# 1. игра, группа, альбом, песня, выпустить, версия, the
# 13. клуб, команда, сезон, матч, сборная, выступать, игра
# 20. олимпийский игра, свой история, игра, завоевать медаль, летний олимпийский, принимать участие, участие летний

# %% [markdown]
# ## 6.

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary)
corpus = tfidf[corpus]

# %% [markdown]
# ## 7.

# %%
ldas_tfidf = {}

# %%
ldas_tfidf['lda_1'] = gensim.models.LdaMulticore(corpus,
                                                 num_topics=20,
                                                 id2word=dictionary,
                                                 passes=30)

# %%
ldas_tfidf['lda_2'] = gensim.models.LdaMulticore(corpus,
                                                 num_topics=20,
                                                 alpha='asymmetric',
                                                 id2word=dictionary,
                                                 passes=30)

# %%
ldas_tfidf['lda_3'] = gensim.models.LdaMulticore(corpus,
                                                 num_topics=20,
                                                 alpha=10,
                                                 id2word=dictionary,
                                                 passes=30)

# %%
ldas_tfidf['lda_4'] = gensim.models.LdaMulticore(corpus,
                                                 num_topics=20,
                                                 alpha=0.001,
                                                 id2word=dictionary,
                                                 passes=30)

# %%
ldas_tfidf['lda_5'] = gensim.models.LdaMulticore(corpus,
                                                 num_topics=20,
                                                 eta=10,
                                                 id2word=dictionary,
                                                 passes=30)

# %%
ldas_tfidf['lda_6'] = gensim.models.LdaMulticore(corpus,
                                                 num_topics=20,
                                                 eta=0.001,
                                                 id2word=dictionary,
                                                 passes=30)

# %%
for lda in ldas_tfidf:
    print(lda)
    pretty_print_topics(ldas_tfidf[lda])
# Out:
# lda_1
# 1. олимпийский игра, свой история, завоевать медаль, летний олимпийский, участие летний, игра, зимний олимпийский
#
# 2. фамилия известный, носитель, мюнхен фрг, меридиан восточный, тепловоз, пуэрто-рико принимать, ямайка принимать
#
# 3. улица, различный населить, родиться чешуекрылый, азербайджан, ссср, армения, остров
#
# 4. южный корея, вещество, турнир, открытый чемпионат, родиться подсемейство, белок, словакия
#
# 5. армия, война, дивизия, фронт, войско, командир, бой
#
# 6. жук, округ, радужница, таджикистан, вид жук-листоед, хутор аксайский, надкрылья
#
# 7. почтовый индекс, телефонный код, занимать площадь, коатуа население, область код, перепись составлять, км² житомирский
#
# 8. романовский район, романовский р-н, литература, емильчинский район, емильчинский р-н, ивановка, село
#
# 9. составлять почтовый, индекс телефонный, код занимать, площадь км², основать находиться, код коатуа, коростенский район
#
# 10. альбом, песня, группа, выпустить, the, игра, уезд
#
# 11. село, сельский совет, харьковский область, расстояние км, составлять м/ж, река, район харьковский
#
# 12. овручский р-н, овручский район, составлять почтовый, индекс телефонный, код занимать, площадь км², код коатуа
#
# 13. уезд, специальный район, флаг, городской округ, городской уезд, кнр, аббревиатура
#
# 14. клуб, команда, сезон, матч, чемпионат, сборная, турнир
#
# 15. сельский поселение, хутор, хорошевский р-н, село, район ростовский, посёлок, поселение
#
# 16. вид, семейство, cryptocephalus, река, встречаться, растение, лист
#
# 17. название населить, пункт, пулинский район, пулинский р-н, соломонов остров, соревнование дзюдо, проводиться
#
# 18. фильм, театр, актёр, роль, режиссёр, актриса, волость
#
# 19. остров, сын, группа, университет, страна, язык, сша
#
# 20. коростышевский р-н, фамилия, коростышевский район, топоним, находиться коростышевский, женский, белокалитвинский район
#
# lda_2
# 1. олимпийский игра, игра, свой история, завоевать медаль, летний олимпийский, участие летний, значение
#
# 2. армия, дивизия, означать, список, командир, фронт, войско
#
# 3. составлять почтовый, индекс телефонный, код занимать, площадь км², основать находиться, район житомирский, код коатуа
#
# 4. радужница, юрий, имаго длина, подсемейство радужница, характеризоваться следующий, жук питаться, македонский
#
# 5. футбольный клуб, проводить стадион, домашний матч, клуб, вмещать зритель, основать, вместимость зритель
#
# 6. михаил, клуб, проект, игра, команда, сезон, олимпийский игра
#
# 7. суворов, first, коэн, кавер-версия песня, леонард, мини-альбом, фильм
#
# 8. фамилия известный, носитель, опытный, английский, испанский, русский, священный римский
#
# 9. географический, сломать, древесный, гриб, питаться, насчитывать, дерево
#
# 10. снукерный турнир, матч фрейм, чемпионат великобритания, профессиональный рейтинговый, великобритания снукер, снукер чемпионат, финал
#
# 11. село, флаг, песня, войско, церковь, театр, городище
#
# 12. житомир, значение, проволока, радужница, альбом, очистить, фильм
#
# 13. библиотекарь, фильм, хутор, программа, пользователь, эда, институт
#
# 14. село, территория, хутор, улица, остров, команда, сельский поселение
#
# 15. выборг, перечислить, вдоль побережье, село, сеть, арнольд, шпицберген
#
# 16. одеяло, язык, власть, фронт, река, моррис, газета
#
# 17. цыган, клуб, корпус, село, матч, royal, войско
#
# 18. группа, луи, паровоз, еврей, плато, вид, история
#
# 19. фиджи принимать, фиджи летний, дзюдо лёгкий, уайт, велоспорт, представлять спортсмен, олимпийский игра
#
# 20. флоренция, библиотека, округ, версия, microsoft, венеция, воронежский
#
# lda_3
# 1. площадь км², село, код занимать, экипаж, способ, занимать площадь, основать находиться
#
# 2. олимпийский игра, индекс телефонный, район житомирский, код коатуа, составлять почтовый, перепись составлять, крепость
#
# 3. село, рынок, поставить, цветок, площадь км², отдел, сохранить
#
# 4. мексика, завоевать медаль, заменить, пьеса, составлять почтовый, деньга, глава
#
# 5. основать находиться, село, индекс телефонный, водохранилище, площадь км², занимать площадь, составлять почтовый
#
# 6. составлять почтовый, иванович, площадь км², власть, союз, поезд, олимпийский игра
#
# 7. проиграть, индекс телефонный, певица, мюнхен фрг, нью-йорк, выходить, основать находиться
#
# 8. основать находиться, сериал, находиться любарский, площадь км², упоминаться, собственный, индекс телефонный
#
# 9. почтовый индекс, перепись составлять, код занимать, село, игра, архитектура, код коатуа
#
# 10. код занимать, олимпийский игра, пол, лугинский район, 5-й, село, хороший экипаж
#
# 11. составлять почтовый, площадь км², вынудить, афины греция, олимпийский игра, одновременно, продолжать
#
# 12. код занимать, олимпийский игра, впоследствии, село, составлять почтовый, преобразовать, пулинский р-н
#
# 13. олимпийский игра, площадь км², участник, район житомирский, индекс телефонный, выход, вместо
#
# 14. село, греция, предложить, план, индекс телефонный, свой история, код занимать
#
# 15. индекс телефонный, село, приказ, составлять почтовый, усср село, олимпийский игра, км² житомирский
#
# 16. индекс телефонный, олимпийский игра, составлять почтовый, представить, аэропорт, телефонный код, мировой война
#
# 17. академия, площадь км², обнаружить, составлять почтовый, командовать, индекс телефонный, константиновский район
#
# 18. олимпийский игра, код занимать, село, коатуа население, отправиться, захватить, температура
#
# 19. олимпийский игра, село, код занимать, записать, бронзовый медаль, радомышльский район, игра
#
# 20. код занимать, составлять почтовый, комиссия, событие, залив, начинаться, полуостров
#
# lda_4
# 1. альбом, песня, фильм, группа, театр, музыка, роль
#
# 2. система, использовать, игра, вид, использоваться, компания, форма
#
# 3. индекс телефонный, составлять почтовый, код занимать, площадь км², село, основать находиться, код коатуа
#
# 4. сын, дом, университет, школа, церковь, село, русский
#
# 5. почтовый индекс, телефонный код, занимать площадь, район житомирский, коатуа население, область код, перепись составлять
#
# 6. фамилия, чудновский район, провинция жужевать, район ростовский, город аксай, посёлок, расположить км
#
# 7. клуб, команда, сезон, матч, сборная, чемпионат, выступать
#
# 8. волость, лугинский район, лугинский р-н, сельсовет, ивановка, уезд, входить состав
#
# 9. остров, cryptocephalus, турнир, финал, вид подсемейство, снукер, матч
#
# 10. находиться чудновский, область чудновский, р-н пгт, бразилия, ул.октябрьский тело, ленин, каменка
#
# 11. значение, уезд, означать, специальный район, флаг, городской округ, символ
#
# 12. филиппина принимать, филиппина летний, таджикистан, суринам принимать, суринам летний, молдавия, крымский область
#
# 13. код коатуа, код занимать, составлять почтовый, индекс телефонный, основать находиться, площадь км², малинский район
#
# 14. армия, дивизия, командир, бой, корабль, фронт, сентябрь
#
# 15. вид, семейство, растение, лист, встречаться, подсемейство, личинка
#
# 16. романовский район, романовский р-н, фамилия известный, носитель, тепловоз, соревнование бокс, вещество
#
# 17. озеро, река, улица, остров, население, коммуна, округ
#
# 18. симфония, samsung, шри-ланка, берёзовый, шостакович, облисполком, плеер оснастить
#
# 19. олимпийский игра, свой история, завоевать медаль, летний олимпийский, участие летний, игра, зимний олимпийский
#
# 20. район ростовский, ростовский область, хутор, входить состав, уезд, литература, сельский поселение
#
# lda_5
# 1. меридиан восточный, вид, северный полюс, алексеев, южный полюс, листоед, лист
#
# 2. меридиан восточный, северный полюс, вид, южный полюс, семейство листоед, вид жуков, лист
#
# 3. жуков семейство, листоед, вид, меридиан восточный, длина мм, лист, подсемейство хризомелин
#
# 4. меридиан восточный, вид, северный полюс, листоед, южный полюс, жуков семейство, лист
#
# 5. название населить, пункт, фамилия, россия, украина, женский, форма
#
# 6. село, река, посёлок, уезд, сельский поселение, улица, поселение
#
# 7. составлять почтовый, индекс телефонный, код занимать, площадь км², основать находиться, код коатуа, новоград-волынский р-н
#
# 8. листоед, вид, меридиан восточный, буква, жуков семейство, лист, длина мм
#
# 9. олимпийский игра, игра, свой история, завоевать медаль, летний олимпийский, участие летний, зимний олимпийский
#
# 10. меридиан восточный, вид, северный полюс, южный полюс, алексеев, лист, листоед
#
# 11. родиться чешуекрылый, семейство белянка, род, подсемейство pierinae, входить, подсемейство, меридиан восточный
#
# 12. вид, семейство листоед, вид жуков, подсемейство хризомелин, семейство, меридиан восточный, фильм
#
# 13. значение, означать, топоним, аббревиатура, многозначный, уезд, символ
#
# 14. фамилия известный, носитель, улица, различный населить, болгарский, индийский, пункт
#
# 15. смирнов, вид, меридиан восточный, листоед, сергеевич, тепловоз, жуков семейство
#
# 16. остров, западный ладожский, остров ладожский, группа, вид, метр, остров архипелаг
#
# 17. телефонный код, почтовый индекс, занимать площадь, коатуа население, область код, перепись составлять, км² житомирский
#
# 18. cryptocephalus, вид подсемейство, европа, встречаться, северный, франция, центральный
#
# 19. топоним, вид, меридиан восточный, листоед, жуков семейство, россия, формула
#
# 20. вид, семейство, распределение, меридиан восточный, оболочка, тепловоз, лист
#
# lda_6
# 1. флаг, аббревиатура, символ, герб, язык, чили зимний, многозначный
#
# 2. храм, хутор белокалитвинский, монастырь, собор, девушка, белокалитвинский район, церковь
#
# 3. индекс телефонный, составлять почтовый, код занимать, площадь км², основать находиться, код коатуа, коростенский район
#
# 4. сын, компания, университет, король, страна, книга, язык
#
# 5. армия, дивизия, командир, фронт, войско, бой, война
#
# 6. олимпийский игра, свой история, завоевать медаль, участие летний, сборная страна, участие зимний, летний олимпийский
#
# 7. топоним, воронежский область, сельский поселение, армянский, россошанский район, остров, армения
#
# 8. вид, семейство, остров, встречаться, улица, подсемейство, личинка
#
# 9. система, список, игра, область народичский, находиться народичский, модель, тринидад тобаго
#
# 10. значение, альбом, песня, группа, означать, сингл, выпустить
#
# 11. км² житомирский, почтовый индекс, телефонный код, коатуа население, занимать площадь, перепись составлять, область код
#
# 12. музыка, художник, музей, песня, музыкальный, композитор, искусство
#
# 13. cryptocephalus, уезд, волость, народичский р-н, находиться народичский, вид подсемейство, народичский район
#
# 14. занимать площадь, телефонный код, почтовый индекс, область код, коатуа население, перепись составлять, район житомирский
#
# 15. фильм, новоград-волынский р-н, новоград-волынский район, уезд, роль, театр, режиссёр
#
# 16. листоед, герой социалистический, совет лозовский, харьковский, люксембург летний, труд, жуков семейство
#
# 17. летний олимпийский, зимний олимпийский, игра, принимать участие, свой история, завоевать медаль, коростышевский р-н
#
# 18. остров, лист, растение, вид, родиться чешуекрылый, входить, род
#
# 19. село, посёлок, река, улица, хутор, название населить, сельский поселение
#
# 20. клуб, команда, сезон, матч, турнир, чемпионат, сборная

# %% [markdown]
# ## 8.

# %%
pretty_print_topics(ldas['lda_4'])
# Out:
# 1. игра, группа, альбом, песня, выпустить, версия, the
#
# 2. турнир, король, открытый чемпионат, финал, выиграть, пара, пешка
#
# 3. страна, право, государство, россия, закон, общество, сша
#
# 4. армия, войско, фронт, война, дивизия, август, военный
#
# 5. дело, суд, москва, убийство, убить, арестовать, март
#
# 6. корабль, самолёт, война, флот, войско, отряд, военный
#
# 7. система, автомобиль, использовать, использоваться, модель, тип, значение
#
# 8. остров, река, озеро, территория, северный, вода, экспедиция
#
# 9. индекс телефонный, составлять почтовый, площадь км², код занимать, район житомирский, основать находиться, занимать площадь
#
# 10. университет, институт, школа, профессор, окончить, ссср, книга
#
# 11. фильм, книга, роль, серия, доктор, ребёнок, отец
#
# 12. церковь, сын, храм, король, святой, здание, монастырь
#
# 13. клуб, команда, сезон, матч, сборная, выступать, игра
#
# 14. партия, член, совет, президент, правительство, выборы, политический
#
# 15. вид, растение, семейство, лист, встречаться, животное, некоторый
#
# 16. гонка, сезон, команда, чемпионат мир, декабрь, победа, февраль
#
# 17. село, посёлок, улица, деревня, хутор, поселение, население
#
# 18. уезд, театр, специальный район, музыка, режиссёр, музыкальный, создать
#
# 19. компания, проект, производство, язык, предприятие, россия, крупный
#
# 20. олимпийский игра, свой история, игра, завоевать медаль, летний олимпийский, принимать участие, участие летний

# %%
pretty_print_topics(ldas_tfidf['lda_1'])
# Out:
# 1. олимпийский игра, свой история, завоевать медаль, летний олимпийский, участие летний, игра, зимний олимпийский
#
# 2. фамилия известный, носитель, мюнхен фрг, меридиан восточный, тепловоз, пуэрто-рико принимать, ямайка принимать
#
# 3. улица, различный населить, родиться чешуекрылый, азербайджан, ссср, армения, остров
#
# 4. южный корея, вещество, турнир, открытый чемпионат, родиться подсемейство, белок, словакия
#
# 5. армия, война, дивизия, фронт, войско, командир, бой
#
# 6. жук, округ, радужница, таджикистан, вид жук-листоед, хутор аксайский, надкрылья
#
# 7. почтовый индекс, телефонный код, занимать площадь, коатуа население, область код, перепись составлять, км² житомирский
#
# 8. романовский район, романовский р-н, литература, емильчинский район, емильчинский р-н, ивановка, село
#
# 9. составлять почтовый, индекс телефонный, код занимать, площадь км², основать находиться, код коатуа, коростенский район
#
# 10. альбом, песня, группа, выпустить, the, игра, уезд
#
# 11. село, сельский совет, харьковский область, расстояние км, составлять м/ж, река, район харьковский
#
# 12. овручский р-н, овручский район, составлять почтовый, индекс телефонный, код занимать, площадь км², код коатуа
#
# 13. уезд, специальный район, флаг, городской округ, городской уезд, кнр, аббревиатура
#
# 14. клуб, команда, сезон, матч, чемпионат, сборная, турнир
#
# 15. сельский поселение, хутор, хорошевский р-н, село, район ростовский, посёлок, поселение
#
# 16. вид, семейство, cryptocephalus, река, встречаться, растение, лист
#
# 17. название населить, пункт, пулинский район, пулинский р-н, соломонов остров, соревнование дзюдо, проводиться
#
# 18. фильм, театр, актёр, роль, режиссёр, актриса, волость
#
# 19. остров, сын, группа, университет, страна, язык, сша
#
# 20. коростышевский р-н, фамилия, коростышевский район, топоним, находиться коростышевский, женский, белокалитвинский район

# %% [markdown]
# Перплексия показывает насколько хороше моделируется корпус. Чем ближе к нулю, тем лучше. Можно использовать, чтобы настраивать количество проходов по корпусу (когда перестало улучшаться, то можно останавливаться).

# %%
best_lda_perplexity = ldas['lda_4'].log_perplexity(corpus)
best_lda_tfidf_perplexity = ldas_tfidf['lda_1'].log_perplexity(corpus)

# %%
print(f'Перплексия лучшей модели без TF-IDF: {best_lda_perplexity}')
print(f'Перплексия лучшей модели с TF-IDF: {best_lda_tfidf_perplexity}')
# Out:
# Перплексия лучшей модели без TF-IDF: -8.097141685172714
# Перплексия лучшей модели с TF-IDF: -9.107181191402598

# %% [markdown]
# Ещё есть когерентность. Она численно оценивает качество тем (проверяется, что темы состоят из разных слов и что в теме есть топ тематических слов).

# %%
np.seterr(divide='warn', invalid='warn')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
[text for text in ngrammed_texts if not text]
# Out:
# []

# %%
def lda_coherence(lda):
    topics = []
    for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
        topic = [word for word, _ in topic]
        topics.append(topic)
    coherence_model_lda = gensim.models.CoherenceModel(topics=topics,
                                                       texts=texts,
                                                       dictionary=dictinary,
                                                       coherence='c_v')
    return coherence_model_lda.get_coherence()

# %%
best_lda_coherence = lda_coherence(ldas['lda_4'])
# Out:
# /Users/liliooon/miniforge3/lib/python3.9/site-packages/gensim/topic_coherence/direct_confirmation_measure.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   m_lr_i = np.log(numerator / denominator)
# /Users/liliooon/miniforge3/lib/python3.9/site-packages/gensim/topic_coherence/indirect_confirmation_measure.py:323: RuntimeWarning: invalid value encountered in double_scalars
#   return cv1.T.dot(cv2)[0, 0] / (_magnitude(cv1) * _magnitude(cv2))

# %%
best_lda_tfidf_coherence = lda_coherence(ldas_tfidf['lda_1'])

# %%
print(f'Когерентность лучшей модели без TF-IDF: {best_lda_coherence}')
print(f'Когерентность лучшей модели с TF-IDF: {best_lda_tfidf_coherence}')
# Out:
# Когерентность лучшей модели без TF-IDF: nan
# Когерентность лучшей модели с TF-IDF: nan

# %%
best_lda_coherence = gensim.models.CoherenceModel(model=ldas['lda_4'],
                                                  corpus=corpus,
                                                  texts=texts,
                                                  coherence='c_v').get_coherence()
# Out:
# /Users/liliooon/miniforge3/lib/python3.9/site-packages/gensim/topic_coherence/direct_confirmation_measure.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   m_lr_i = np.log(numerator / denominator)
# /Users/liliooon/miniforge3/lib/python3.9/site-packages/gensim/topic_coherence/indirect_confirmation_measure.py:323: RuntimeWarning: invalid value encountered in double_scalars
#   return cv1.T.dot(cv2)[0, 0] / (_magnitude(cv1) * _magnitude(cv2))

# %%
best_lda_tfidf_coherence = gensim.models.CoherenceModel(model=ldas_tfidf['lda_1'],
                                                        texts=texts,
                                                        dictionary=dictinary,
                                                        coherence='c_v').get_coherence()
# Out:
# /Users/liliooon/miniforge3/lib/python3.9/site-packages/gensim/topic_coherence/direct_confirmation_measure.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   m_lr_i = np.log(numerator / denominator)
# /Users/liliooon/miniforge3/lib/python3.9/site-packages/gensim/topic_coherence/indirect_confirmation_measure.py:323: RuntimeWarning: invalid value encountered in double_scalars
#   return cv1.T.dot(cv2)[0, 0] / (_magnitude(cv1) * _magnitude(cv2))

# %%
print(f'Когерентность лучшей модели без TF-IDF: {best_lda_coherence}')
print(f'Когерентность лучшей модели с TF-IDF: {best_lda_tfidf_coherence}')
# Out:
# Когерентность лучшей модели без TF-IDF: nan
# Когерентность лучшей модели с TF-IDF: nan

# %% [markdown]
# Чем выше, тем лучше.

# %% [markdown]
# ## 9.

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %%
stexts = [' '.join(text) for text in texts]

# %%
vectorizer = TfidfVectorizer(max_features=2000, min_df=10, max_df=0.1, ngram_range=(1,2))
X = vectorizer.fit_transform(stexts)

# %%
# n_components - главный параметр в NMF, это количество тем. 
# Если данных много, то увеличения этого параметра сильно увеличивает время обучения
model = NMF(n_components=100)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=100, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
model.components_.shape # матрица темы на слова
# Out:
# (100, 2000)

# %%
model.transform(X).shape # матрица документы на темы
# Out:
# (10000, 100)

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
feat_names = vectorizer.get_feature_names()

# %%
top_words = model.components_.argsort()[:,:-5:-1]

for i in range(top_words.shape[0]):
    words = [feat_names[j] for j in top_words[i]]
    print(i, "--".join(words))
# Out:
# 0 летний олимпийский--летний--олимпийский игра--участие летний
# 1 украина основать--год находиться--области код--составлять человек
# 2 век--xix--xix век--xx
# 3 расстояние километр--харьковский--расстояние--километр расположить
# 4 зимний олимпийский--зимний--олимпийский игра--участие зимний
# 5 украина находиться--области код--составлять человек--ул
# 6 новоград--новоград волынский--волынский--области население
# 7 клуб--матч--лига--забить
# 8 хутор--ростовский--район ростовский--ростовский области
# 9 ул--наш ул--карл--области население
# 10 род--подсемейство--около--некоторый
# 11 сын--отец--жена--ребёнок
# 12 овручский--области код--сергей--13
# 13 остров--относиться--километр--пролив
# 14 емильчинский--области код--украина находиться--23
# 15 населить пункт--населить--пункт--государство
# 16 уезд--год уезд--специальный район--округ
# 17 хорошевский--области население--украина находиться--украина основать
# 18 альбом--the--of--выпустить
# 19 коростенский--области код--украина основать--год находиться
# 20 фильм--режиссёр--роль--картина
# 21 граф--де--ii--графство
# 22 усср--год указ--1946--1946 год
# 23 река--приток--бассейн--берег
# 24 км²--площадь км²--совет--сель
# 25 радомышльский--украина находиться--области код--протекать
# 26 коростышевский--области население--украина находиться--украина основать
# 27 улица--москва--бывший--государство
# 28 фамилия--женский--форма--русский
# 29 чемпионат--мир--чемпионат мир--среди
# 30 поселение--сельский--сельский поселение--муниципальный образование
# 31 малинский--области код--площадь км²--украина основать
# 32 ул ленин--ленин--ул--19
# 33 семейство--роды--подсемейство--растение
# 34 длина--сантиметр--мм--диаметр
# 35 медаль сборная--сборная страна--сборная--страна представлять
# 36 церковь--храм--епархия--собор
# 37 романовский--области население--украина основать--год находиться
# 38 великий--отечественный--великий отечественный--отечественный война
# 39 экипаж--финал--раунд--сильнейший
# 40 житомирский сесть--ул--19--области население
# 41 волость--брянский--сельсовет--территориальный
# 42 турнир--финал--профессиональный--победитель
# 43 подсемейство--европа--встречаться--распространить
# 44 посёлок--дорога--городской--километр
# 45 институт--научный--наука--профессор
# 46 озеро--берег--глубина--вода
# 47 станция--дорога--линия--железнодорожный
# 48 университет--факультет--профессор--школа
# 49 километр--восток--запад--северо
# 50 гонка--кубок--этап--кубок мир
# 51 наш тело--35--1900--площадь км²
# 52 означать--слово--коммуна--буква
# 53 иван--василий--князь--николай
# 54 язык--индия--распространить--слово
# 55 список--дата--представить--орден
# 56 армия--генерал--войско--военный
# 57 использовать--использоваться--форма--случай
# 58 роль--театр--актёр--сериал
# 59 завод--предприятие--производство--мощность
# 60 ростовский область--ростовский--памятник--культура
# 61 департамент--провинция--административный--численность
# 62 флаг--символ--цвета--герб
# 63 спортсмен--соревнование--атлетика--раунд
# 64 значение--термин--символ--запись
# 65 село--сель--протекать--сельский
# 66 северный--полюс--южный--океан
# 67 группа--участник--играть--коллектив
# 68 компания--разработка--серия--выпустить
# 69 музыка--музыкальный--оркестр--композитор
# 70 король--пешка--сын--норвегия
# 71 ул центральный--центральный--наш ул--европа
# 72 художник--искусство--живопись--художественный
# 73 деревня--сельсовет--коммуна--двор
# 74 корабль--флот--морской--крейсер
# 75 автомобиль--двигатель--модель--машина
# 76 россия--российский--русский--москва
# 77 птица--чёрный--самка--цвет
# 78 растение--личинка--питаться--лист
# 79 святой--епископ--память--день
# 80 сша--американский--штат--нью
# 81 премия--хороший--награда--номинация
# 82 дивизия--1941--1941 год--1944
# 83 канада--канадский--1976--1976 год
# 84 ссср--тренер--спорт--советский
# 85 совет--председатель--верховный--комитет
# 86 музей--норвежский--коллекция--выставка
# 87 книга--писатель--роман--журнал
# 88 министр--премьер министр--премьер--правительство
# 89 партия--политический--выборы--выбор
# 90 2009--2009 год--2008--2008 год
# 91 31--10--март--области код
# 92 система--компьютер--управление--помощь
# 93 команда--сезон--выступать--лига
# 94 2010--2010 год--март--18
# 95 парк--национальный--гора--норвежский
# 96 аэропорт--ан--самолёт--региональный
# 97 здание--дом--построить--проект
# 98 герой--советский--герой советский--советский союз
# 99 песня--песнь--сингл--певица

# %% [markdown]
# ## 10.

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью BigARTM**.
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор)
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases, можно также попробовать другие способы построить нграммы);
#
# 3) сохраните тексты .vw формате;
#
# 4) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова, сохраните словарь и посмотрите на него, вдруг что-то плохое сразу будет заметно - из словаря можно просто вручную или правилом удалять строки, при загрузке ничего не сломается);
#
# 5) постройте несколько ARTM моделей (переберите количество тем, поменяйте значения tau у регуляризаторов), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 6) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы
#
# 7) в другой ячейке нарисуйте график обучения этой модели
#
# 8) в третьей ячейки опишите какие параметры (количество тем, регуляризаторы, их tau) вы использовали и как обучали (например, после скольки проходов добавили регуляризатор разрежнивания тем (Phi), добавляли ли разреженность документам (Theta) и когда, как повышали значения, сколько итерации модель продожала улучшаться (снижалась перплексия, росли другие метрики);
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 6, 7 и 8. (3, 1, 4 баллов соответственно). Чтобы заработать остальные 2 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **
